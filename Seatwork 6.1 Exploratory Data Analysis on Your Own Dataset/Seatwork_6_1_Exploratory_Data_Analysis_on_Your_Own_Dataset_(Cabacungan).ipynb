# %% [markdown]
# # Seatwork 6.1 Exploratory Data Analysis on Your Own Dataset
# Name: Cabacungan, John Martin C.
#
# Section: CPE22S3
#
# Performed On: 03/11/2024
#
# Submitted On: 03/11/2024
#
# Submitted to: Engr. Roman M. Richard
#
# Instructions:
#
# * Choose your own dataset from public repositories.
#
# * Link your chosen dataset in this spreadsheet: Dataset SpreadsheetLinks to an external site.
#
# * Perform simple exploratory data analysis using descriptive statistics.
#
# * Employ the same steps as done in the hands-on activity and provide your own analysis of the dataset.
#
# * Your submission must include your GitHub folder link that includes a customized readme file, Python Notebook Files, Dataset, and a simple presentation of your findings.
#
#
# Note:
#
# Graphing is not required but may be done for additional points.

# %%
filepath = '/content/strong.csv'

# %%
filepath
# Out:
# '/content/strong.csv'

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(filepath, index_col='Date')

# %%
df
# Out:
#                     Workout Name Duration             Exercise Name  \
# Date
# 2021-09-13 10:41:41       PUSH 1   1h 12m     Bench Press (Barbell)
# 2021-09-13 10:41:41       PUSH 1   1h 12m     Bench Press (Barbell)
# 2021-09-13 10:41:41       PUSH 1   1h 12m     Bench Press (Barbell)
# 2021-09-13 10:41:41       PUSH 1   1h 12m     Bench Press (Barbell)
# 2021-09-13 10:41:41       PUSH 1   1h 12m   Incline Cable Chest Fly
# ...                          ...      ...                       ...
# 2024-02-02 17:37:32      PULL 2       30m  Lateral Raise (Dumbbell)
# 2024-02-02 17:37:32      PULL 2       30m        Seated Row (Cable)
# 2024-02-02 17:37:32      PULL 2       30m        Seated Row (Cable)
# 2024-02-02 17:37:32      PULL 2       30m        Seated Row (Cable)
# 2024-02-02 17:37:32      PULL 2       30m        Seated Row (Cable)
#
#                      Set Order  Weight  Reps  Distance  Seconds Notes  \
# Date
# ...

# %%
# Identifying the column names
df.columns
# Out:
# Index(['Workout Name', 'Duration', 'Exercise Name', 'Set Order', 'Weight',
#        'Reps', 'Distance', 'Seconds', 'Notes', 'Workout Notes', 'RPE'],
#       dtype='object')

# %%
# Identify the data types of the data
df.dtypes
# Out:
# Workout Name      object
# Duration          object
# Exercise Name     object
# Set Order          int64
# Weight           float64
# Reps               int64
# Distance           int64
# Seconds            int64
# Notes             object
# Workout Notes     object
# RPE              float64
# dtype: object

# %%
# The first 20 of the records
df.head(20)
# Out:
#                     Workout Name Duration  \
# Date
# 2021-09-13 10:41:41       PUSH 1   1h 12m
# 2021-09-13 10:41:41       PUSH 1   1h 12m
# 2021-09-13 10:41:41       PUSH 1   1h 12m
# 2021-09-13 10:41:41       PUSH 1   1h 12m
# 2021-09-13 10:41:41       PUSH 1   1h 12m
# 2021-09-13 10:41:41       PUSH 1   1h 12m
# 2021-09-13 10:41:41       PUSH 1   1h 12m
# 2021-09-13 10:41:41       PUSH 1   1h 12m
# 2021-09-13 10:41:41       PUSH 1   1h 12m
# 2021-09-13 10:41:41       PUSH 1   1h 12m
# 2021-09-13 10:41:41       PUSH 1   1h 12m
# 2021-09-13 10:41:41       PUSH 1   1h 12m
# 2021-09-13 10:41:41       PUSH 1   1h 12m
# 2021-09-13 10:41:41       PUSH 1   1h 12m
# 2021-09-13 10:41:41       PUSH 1   1h 12m
# 2021-09-13 10:41:41       PUSH 1   1h 12m
# 2021-09-13 10:41:41       PUSH 1   1h 12m
# 2021-09-13 10:41:41       PUSH 1   1h 12m
# 2021-09-13 10:41:41       PUSH 1   1h 12m
# 2021-09-13 10:41:41       PUSH 1   1h 12m
#
# ...

# %%
# The last 20 of the records
df.tail(20)
# Out:
#                     Workout Name Duration                 Exercise Name  \
# Date
# 2024-02-01 16:02:22       PUSH 2      46m  Incline Chest Fly (Dumbbell)
# 2024-02-01 16:02:22       PUSH 2      46m  Incline Chest Fly (Dumbbell)
# 2024-02-01 16:02:22       PUSH 2      46m  Incline Chest Fly (Dumbbell)
# 2024-02-01 16:02:22       PUSH 2      46m  Incline Chest Fly (Dumbbell)
# 2024-02-01 16:02:22       PUSH 2      46m        Tricep Pushdown (rope)
# 2024-02-01 16:02:22       PUSH 2      46m        Tricep Pushdown (rope)
# 2024-02-01 16:02:22       PUSH 2      46m        Tricep Pushdown (rope)
# 2024-02-01 16:02:22       PUSH 2      46m        Tricep Pushdown (rope)
# 2024-02-02 17:37:32      PULL 2       30m          Lat Pulldown (Cable)
# 2024-02-02 17:37:32      PULL 2       30m          Lat Pulldown (Cable)
# 2024-02-02 17:37:32      PULL 2       30m          Lat Pulldown (Cable)
# 2024-02-02 17:37:32      PULL 2       30m          Lat Pulldown (Cable)
# ...

# %%
# Displaying the total number of records
print('There are', len(df), 'total number of records!')
# Out:
# There are 3989 total number of records!

# %%
# Renaming a certain column from Weight to Heaviness
df.rename(columns = {'Weight':'Heaviness'}, inplace = True)
df
# Out:
#                     Workout Name Duration             Exercise Name  \
# Date
# 2021-09-13 10:41:41       PUSH 1   1h 12m     Bench Press (Barbell)
# 2021-09-13 10:41:41       PUSH 1   1h 12m     Bench Press (Barbell)
# 2021-09-13 10:41:41       PUSH 1   1h 12m     Bench Press (Barbell)
# 2021-09-13 10:41:41       PUSH 1   1h 12m     Bench Press (Barbell)
# 2021-09-13 10:41:41       PUSH 1   1h 12m   Incline Cable Chest Fly
# ...                          ...      ...                       ...
# 2024-02-02 17:37:32      PULL 2       30m  Lateral Raise (Dumbbell)
# 2024-02-02 17:37:32      PULL 2       30m        Seated Row (Cable)
# 2024-02-02 17:37:32      PULL 2       30m        Seated Row (Cable)
# 2024-02-02 17:37:32      PULL 2       30m        Seated Row (Cable)
# 2024-02-02 17:37:32      PULL 2       30m        Seated Row (Cable)
#
#                      Set Order  Heaviness  Reps  Distance  Seconds Notes  \
# Date
# ...

# %%
# creating a new column that displays the set order if there is 1 it shows Max Effort, and 2 and above shows Very Hard
df['Rate of Perceived Exertion'] = np.where(df['Set Order'] == 1, 'Max Effort', 'Very Hard')
df
# Out:
#                     Workout Name Duration             Exercise Name  \
# Date
# 2021-09-13 10:41:41       PUSH 1   1h 12m     Bench Press (Barbell)
# 2021-09-13 10:41:41       PUSH 1   1h 12m     Bench Press (Barbell)
# 2021-09-13 10:41:41       PUSH 1   1h 12m     Bench Press (Barbell)
# 2021-09-13 10:41:41       PUSH 1   1h 12m     Bench Press (Barbell)
# 2021-09-13 10:41:41       PUSH 1   1h 12m   Incline Cable Chest Fly
# ...                          ...      ...                       ...
# 2024-02-02 17:37:32      PULL 2       30m  Lateral Raise (Dumbbell)
# 2024-02-02 17:37:32      PULL 2       30m        Seated Row (Cable)
# 2024-02-02 17:37:32      PULL 2       30m        Seated Row (Cable)
# 2024-02-02 17:37:32      PULL 2       30m        Seated Row (Cable)
# 2024-02-02 17:37:32      PULL 2       30m        Seated Row (Cable)
#
#                      Set Order  Heaviness  Reps  Distance  Seconds Notes  \
# Date
# ...

# %%
# This shows all of the data that have 1 in their Set Order
ndf = pd.DataFrame(df)
ndf = df[df['Set Order'] == 1].copy()

ndf
# Out:
#                     Workout Name Duration  \
# Date
# 2021-09-13 10:41:41       PUSH 1   1h 12m
# 2021-09-13 10:41:41       PUSH 1   1h 12m
# 2021-09-13 10:41:41       PUSH 1   1h 12m
# 2021-09-13 10:41:41       PUSH 1   1h 12m
# 2021-09-13 10:41:41       PUSH 1   1h 12m
# ...                          ...      ...
# 2024-02-01 16:02:22       PUSH 2      46m
# 2024-02-01 16:02:22       PUSH 2      46m
# 2024-02-02 17:37:32      PULL 2       30m
# 2024-02-02 17:37:32      PULL 2       30m
# 2024-02-02 17:37:32      PULL 2       30m
#
#                                                Exercise Name  Set Order  \
# Date
# 2021-09-13 10:41:41                    Bench Press (Barbell)          1
# 2021-09-13 10:41:41                  Incline Cable Chest Fly          1
# 2021-09-13 10:41:41                Overhead Press (Dumbbell)          1
# 2021-09-13 10:41:41                    Lateral Raise (Cable)          1
# 2021-09-13 10:41:41  Triceps Pushdown (Cable - Straight Bar)          1
# ...

# %%
# This shows the other data sets that only has 2 in the Set Order and Very Hard Rate of Perceived Exertion
ndf = pd.DataFrame(df)
ndf = df[df['Set Order'] == 2].copy()

ndf
# Out:
#                     Workout Name Duration  \
# Date
# 2021-09-13 10:41:41       PUSH 1   1h 12m
# 2021-09-13 10:41:41       PUSH 1   1h 12m
# 2021-09-13 10:41:41       PUSH 1   1h 12m
# 2021-09-13 10:41:41       PUSH 1   1h 12m
# 2021-09-13 10:41:41       PUSH 1   1h 12m
# ...                          ...      ...
# 2024-02-01 16:02:22       PUSH 2      46m
# 2024-02-01 16:02:22       PUSH 2      46m
# 2024-02-02 17:37:32      PULL 2       30m
# 2024-02-02 17:37:32      PULL 2       30m
# 2024-02-02 17:37:32      PULL 2       30m
#
#                                                Exercise Name  Set Order  \
# Date
# 2021-09-13 10:41:41                    Bench Press (Barbell)          2
# 2021-09-13 10:41:41                  Incline Cable Chest Fly          2
# 2021-09-13 10:41:41                Overhead Press (Dumbbell)          2
# 2021-09-13 10:41:41                    Lateral Raise (Cable)          2
# 2021-09-13 10:41:41  Triceps Pushdown (Cable - Straight Bar)          2
# ...

# %%
# this solves the mean of the two columns "Heaviness" and "Reps"
mean = np.mean(df['Heaviness']), np.mean(df['Reps'])
mean
# Out:
# (34.30088994735522, 9.534219102531964)

# %%
# The middle value of the solved mean of Heaviness and Reps
median = np.median(mean)
median
# Out:
# 21.917554524943593

# %%
# solving the standard deviation of Heaviness
std = np.std(df['Heaviness'])
std
# Out:
# 17.709959158111353

# %%
df.describe() #checkin
# Out:
#          Set Order    Heaviness         Reps  Distance      Seconds  \
# count  3989.000000  3989.000000  3989.000000    3989.0  3989.000000
# mean      2.170970    34.300890     9.534219       0.0     0.075207
# std       1.042406    17.712179     3.627689       0.0     4.749952
# min       1.000000     0.000000     0.000000       0.0     0.000000
# 25%       1.000000    25.000000     7.000000       0.0     0.000000
# 50%       2.000000    30.000000     9.000000       0.0     0.000000
# 75%       3.000000    45.000000    12.000000       0.0     0.000000
# max       6.000000   195.000000    30.000000       0.0   300.000000
#
#                RPE
# count  3767.000000
# mean      9.563048
# std       0.684452
# min       6.000000
# 25%       9.000000
# 50%      10.000000
# 75%      10.000000
# max      10.000000
